# %% [markdown]
# <a href="https://colab.research.google.com/github/HamiduI-Islam/Programming-In-Python/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Perform mathematical operations
a = 10
b = 5
print(f"Addition: {a + b}")

print(f"Subtraction: {a - b}")

print(f"Multiplication:{a * b}")

print(f"Division: {a / b}")
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication:50
# Division: 2.0

# %%
#Takeinput values and print output values
name = input("Enter your name: ")
age = input("Enter your age: ")

print("Hello! " + name + " You are " + age+ " years old.")
# Out:
# Enter your name: hamidul
# Enter your age: 24
# Hello! hamidul You are 24 years old.
